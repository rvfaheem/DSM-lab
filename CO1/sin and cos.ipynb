# %%
import numpy as np
import matplotlib.pyplot as plt
 

x = np.arange(0, 5*np.pi, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)
 


plt.plot(x, y1, label='sin', color='red',linestyle='dashed')
plt.plot(x, y2, label='cos',color='green')
plt.legend()
plt.show()
