# %%
import numpy as np
import matplotlib.pyplot as plt 
 
  

data = {'sakthi':20, 'Hari':15, 'sreeraj':30, 
        'Faheem':35}

  
fig = plt.figure(figsize = (10, 5))
 

plt.bar(courses, values, color ='maroon', 
        width = 0.5)
 
plt.xlabel("Students")
plt.ylabel("Height")
plt.title("Students Heights")
plt.show()
