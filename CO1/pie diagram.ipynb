# %%
from matplotlib import pyplot as plt
import numpy as np
 
 

subjects = ["physics","Chemistry","Botony","zoology","Maths","English"]
 
students = [80,60,50,40,60,20]


fig = plt.figure(figsize =(10, 7))
explode=(0.4,0,0,0,0,0)
plt.pie(students,explode=explode ,labels = subjects)
plt.show()
